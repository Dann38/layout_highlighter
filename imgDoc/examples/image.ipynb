# %%
# !python -m pip install "../."
# Out:
# Processing c:\users\danii\program\python\project\imgdoc
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for imgdoc: filename=imgdoc-0.0.2-py3-none-any.whl size=4964 sha256=ba55c7a77603cae3e0f1fe1549305a87935ba9e418d22d07c97037b308154fdb
#   Stored in directory: C:\Users\danii\AppData\Local\Temp\pip-ephem-wheel-cache-4mrvehci\wheels\b8\e3\4a\f1f494124c2259921bd58533df69bb605814dcc87a7223eb4d
# Successfully built imgdoc
# ...
#   Attempting uninstall: imgdoc
#     Found existing installation: imgdoc 0.0.2
#     Uninstalling imgdoc-0.0.2:
#       Successfully uninstalled imgdoc-0.0.2
# ...
# WARNING: Ignoring invalid distribution - (c:\users\danii\scoop\persist\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\danii\scoop\persist\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\danii\scoop\persist\python\lib\site-packages)
# ...

# %%
from img_doc.data_structures import Image, ImageSegment
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(os.path.join("img", "1.jpg"))
image = Image(img)

# %%
plt.imshow(image.img)

# %%
image.get_base64()
# Out:
# b'...'
