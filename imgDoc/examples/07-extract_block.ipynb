# %%
from img_doc.document import Document
# Out:
# 2024-02-22 11:04:32.608943: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 11:04:32.645152: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-22 11:04:32.645181: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-22 11:04:32.646183: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-22 11:04:32.651877: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 11:04:32.652266: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-22 11:04:33.417298: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
doc = Document()
doc.set_from_path("img/1.jpg")

# %%
doc.pages[0].image.plot()

# %%
block = doc.get_info_from_segment(num_page=0, x_top_left=100, y_top_left=170, 
                                  x_bottom_right=950, y_bottom_right=450, 
                                  conf={
                                     "extractor_word":{
                                         "method":"tesseract",
                                         "conf": {"lang": "eng+rus", "psm": 4, "oem": 3, "k": 1},
                                     },
                                      "classification":{
                                          "type": "walk_rnd",
                                          "conf": {
                                              "properties": ["many_dist", "many_angle"], 
                                              "count_step": 50,
                                              "path_model": "../model_training/models/RWMDMA-MP50/"}
                                      },
                                        })

# %%
doc.pages[0].image.plot()
block.segment.plot()
print(f"========= {block.label} ===========")
print(block.get_text())
# Out:
# ========= table ===========
# 1 РАЗРАБОТАН Акционерным обществом «Центр технического и сметного нормирования в стро- ительстве» (АО «ЦНС») 2 ВНЕСЕН Техническим комитетом по стандартизации ТК 465 «Строительство» 3 УТВЕРЖДЕН И ВВЕДЕН В ДЕЙСТВИЕ Приказом Федерального агентства по техническому регулированию и метрологии от 23 июня 2020 г. № 282-ст 4 ВЗАМЕН ГОСТР 21.1101—2013 5 В настоящем стандарте реализованы нормы Федерального закона от 29 декабря 2004 г. № 190-ФЗ. «Градостроительный кодекс Российской Федерации»
