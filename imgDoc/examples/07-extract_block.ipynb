# %%
from img_doc.document import Document
# Out:
# 2024-02-22 11:17:22.921348: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 11:17:22.957218: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-22 11:17:22.957248: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-22 11:17:22.958253: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-22 11:17:22.963795: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 11:17:22.964257: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-22 11:17:23.723825: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
doc = Document()
doc.set_from_path("img/1.jpg")

# %%
doc.pages[0].image.plot()

# %%
conf={
         "extractor_word":{
             "method":"tesseract",
             "conf": {"lang": "eng+rus", "psm": 4, "oem": 3, "k": 1},
         },
          "classification":{
              "type": "walk_rnd",
              "conf": {
                  "properties": ["many_dist", "many_angle"], 
                  "count_step": 50,
                  "path_model": "../model_training/models/RWMDMA-MP50/"}
          },
        }

# %%
block = doc.get_info_from_segment(num_page=0, x_top_left=100, y_top_left=170, 
                                  x_bottom_right=950, y_bottom_right=450, 
                                  conf=conf)

# %%
doc.pages[0].image.plot()
block.segment.plot()
print(f"========= {block.label} ===========")
print(block.get_text())
# Out:
# ========= table ===========
# 1 РАЗРАБОТАН Акционерным обществом «Центр технического и сметного нормирования в стро- ительстве» (АО «ЦНС») 2 ВНЕСЕН Техническим комитетом по стандартизации ТК 465 «Строительство» 3 УТВЕРЖДЕН И ВВЕДЕН В ДЕЙСТВИЕ Приказом Федерального агентства по техническому регулированию и метрологии от 23 июня 2020 г. № 282-ст 4 ВЗАМЕН ГОСТР 21.1101—2013 5 В настоящем стандарте реализованы нормы Федерального закона от 29 декабря 2004 г. № 190-ФЗ. «Градостроительный кодекс Российской Федерации»

# %%
block2 = doc.get_info_from_segment(num_page=0, x_top_left=100, y_top_left=450, 
                                  x_bottom_right=950, y_bottom_right=700, 
                                  conf=conf)

# %%
doc.pages[0].image.plot()
block2.segment.plot()
print(f"========= {block2.label} ===========")
print(block2.get_text())
# Out:
# ========= table ===========
# Правила применения настоящего стандарта установлены в статье 26 Федерального закона. от 29 июня 2015 г. № 162-ФЗ «О стандартизации в Российской Федерации». Информация об из- менениях к настоящему стандарту публикуется в ежегодном (по состоянию на 1 января текущего года) информационном указателе «Национальные стандарты», а официальный текст изменений и поправок — в ежемесячном информационном указателе «Национальные стандарты». В случае пересмотра (замены) или отмены настоящего стандарта соответствующее уведомление будет опубликовано в ближайшем выпуске ежемесячного информационного указателя «Национальные стандарты». Соответствующая информация. уведомление и тексты размещаются также в ин- формационной системе общего пользования — на официальном сайте Федерального агентства по ‘техническому регулированию и метрологии в сети Интернет (или. 9051.ги)

# %%
block3 = doc.get_info_from_segment(num_page=0, x_top_left=100, y_top_left=1200, 
                                  x_bottom_right=950, y_bottom_right=1400, 
                                  conf=conf)
doc.pages[0].image.plot()
block3.segment.plot()
print(f"========= {block3.label} ===========")
print(block3.get_text())
# Out:
# ========= header ===========
# stroystandart.info

# %%
doc = Document()
doc.set_from_path("img/5.jpg")

# %%
doc.pages[0].image.plot()

# %%
block4 = doc.get_info_from_segment(num_page=0, x_top_left=50, y_top_left=270, 
                                  x_bottom_right=1250, y_bottom_right=595, 
                                  conf=conf)
doc.pages[0].image.plot()
block4.segment.plot()
print(f"========= {block4.label} ===========")
print(block4.get_text())
# Out:
# ========= table ===========
# Прямая линия 4. Прямая линия. Самой простой линией является прямая. Представление о прямой линии, или просто о прямой, всем хорошо знакомо. Представление о ней дает туго натянутая нить или луч света, выходящий из малого отверстия. С этим представлением согласуется следующее основное свойство прямой: Через всякие две точки пространства можно провести р ies oe a РУ прямую
