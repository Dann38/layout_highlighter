# %%
from img_doc.data_structures import Document
import matplotlib.pyplot as plt

# %%
doc = Document()

# %%
doc.set_from_path("./pdf/Rosenblatt1958.pdf")

# %%
figure = plt.figure(dpi=500)
plt.imshow(doc.pages[2].image.img)
