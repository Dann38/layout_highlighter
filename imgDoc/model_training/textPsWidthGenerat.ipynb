# %%
from img_doc.extractors.word_extractors.word_bold_extractor import TextPsBoldExtractor
import os

# %%
ext_bold = TextPsBoldExtractor()

# %%
dir_path = "../src/img_doc/extractors/word_extractors/word_bold_extractor/cluster_word_bold_extractor/text_ps_bold_extractor/"
path_bold = os.path.join(dir_path, "bold.ttf")
path_reg = os.path.join(dir_path, "reg.ttf")
rez = ext_bold.create_width_from_tff(path_ttf_bold=path_bold, path_ttf_regular=path_reg, size=60)

# %%
for key, item in rez.items():
    rez[key] = round(item, 3)

# %%
rez
# Out:
# {'А': 0.87,
#  'Б': 0.675,
#  'В': 0.742,
#  'Г': 0.661,
#  'Д': 0.852,
#  'Е': 0.582,
#  'Ж': 0.8,
#  'З': 0.833,
#  'И': 0.706,
#  'Й': 0.779,
#  'К': 0.675,
#  'Л': 0.678,
#  'М': 0.738,
#  'Н': 0.658,
#  'О': 0.676,
#  'П': 0.663,
#  'Р': 0.72,
#  'С': 0.778,
#  'Т': 0.638,
#  'У': 0.706,
#  'Ф': 0.767,
#  'Х': 0.765,
#  'Ц': 0.666,
#  'Ч': 0.663,
#  'Ш': 0.985,
#  'Щ': 1.024,
#  'Ъ': 0.714,
#  'Ы': 0.754,
#  'Ь': 0.707,
#  'Э': 0.807,
#  'Ю': 0.881,
#  'Я': 0.691,
#  'а': 0.706,
#  'б': 0.821,
#  'в': 0.748,
#  'г': 0.725,
#  'д': 0.817,
#  'е': 0.878,
#  'ж': 0.665,
#  'з': 0.863,
#  'и': 0.728,
#  'й': 0.746,
#  'к': 0.624,
#  'л': 0.67,
#  'м': 0.772,
#  'н': 0.709,
#  'о': 0.755,
#  'п': 0.697,
#  'р': 0.774,
#  'с': 0.804,
#  'т': 0.76,
#  'у': 0.809,
#  'ф': 0.748,
#  'х': 0.832,
#  'ц': 0.709,
#  'ч': 0.706,
#  'ш': 0.665,
#  'щ': 0.683,
#  'ъ': 0.607,
#  'ы': 0.731,
#  'ь': 0.764,
#  'э': 0.822,
#  'ю': 0.73,
#  'я': 0.657,
#  '0': 0.723,
#  '1': 0.57,
#  '2': 0.671,
# ...

# %%
for i in "abc":
    print(i)
# Out:
# a
# b
# c
